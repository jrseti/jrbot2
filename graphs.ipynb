# %%
import sys
import plotly.graph_objects as go
import pandas as pd
import sqlalchemy
from config import *
from urllib.parse import quote_plus
from ts_auth0 import TS_Auth
import requests

# %%
def getDf(ticker, start_date, end_date):
    # Create the database engine
    url = f'mysql://{DB_USER}:{quote_plus(DB_PASS)}@{DB_HOST}:{DB_PORT}/{DB_NAME}'
    #print(url)
    engine = sqlalchemy.create_engine(url)

    query  = f"SELECT * FROM bars_1min WHERE ticker='{ticker}' AND "
    query += f"datetime >= '{start_date}' AND "
    query += f"datetime <= '{end_date}' "
    query += "ORDER BY datetime ASC"

    df = None
    with engine.connect() as conn:
        df = pd.read_sql(query, con = conn)

    #display(df)

    return df

# %%
# Out:
#       id  ticker            datetime    open    high     low   close  volume  \
# 0  83787  RTYU23 2023-08-08 07:00:00  1956.9  1957.2  1956.7  1957.1      13
# 1  83788  RTYU23 2023-08-08 07:01:00  1957.2  1957.3  1956.5  1957.1     122
# 2  83789  RTYU23 2023-08-08 07:02:00  1957.0  1957.5  1956.6  1956.8     120
# 3  83790  RTYU23 2023-08-08 07:03:00  1956.6  1957.1  1955.8  1957.1     146
# 4  83791  RTYU23 2023-08-08 07:04:00  1957.0  1957.3  1956.7  1956.9      57
#
#    open_interest
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df = getDf('RTYU23', '2023-08-09T00:00:00Z', '2023-08-09T18:30:00Z')

fig = go.Figure(data=[go.Candlestick(x=df['datetime'],
                open=df['open'],
                high=df['high'],
                low=df['low'],
                close=df['close'])])

fig.show()
# Out:
# <div>                            <div id="589c459b-e737-4377-a9b8-20f2610ec345" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("589c459b-e737-4377-a9b8-20f2610ec345")) {                    Plotly.newPlot(                        "589c459b-e737-4377-a9b8-20f2610ec345",                        [{"close":[1952.9,1952.6,1952.5,1952.5,1952.4,1952.6,1952.6,1952.7,1952.9,1953.1,1954.4,1954.1,1954.0,1954.7,1954.5,1954.5,1955.2,1954.9,1954.8,1954.7,1954.8,1955.1,1955.0,1954.8,1954.5,1954.5,1954.1,1954.2,1954.0,1954.5,1954.7,1955.4,1955.1,1955.0,1955.2,1955.2,1954.7,1954.6,1954.8,1954.7,1954.7,1954.6,1954.8,1954.8,1954.7,1954.5,1955.0,1954.8,1954.7,1954.9,1954.7,1954.7,1954.9,1954.8,1954.6,1954.8,1954.8,1955.0,1955.4,1955.4,1955.5,1955.5,1955.4,1955.5,1955.6,1956.2,1956.1,1956.0,1956.3,1956.5,1956.6,1956.3,1955.8,1955.8,1956.2,1956.0,1955.9,1956.0,1956.0,1956.3,1956.1,1956.1,1956.2,1956.0,1956.0,1956.0,1956.2,1956.3,1956.3,1956.2,1956.3,1956.6,1956.4,1956.1,1956.3,1956.7,1956.7,1956.6,1956.5,1956.5,1956.7,1956.7,1956.9,1957.0,1957.0,1956.9,1956.7,1956.3,1956.1,1956.0,1956.0,1955.4,1955.4,1955.9,1956.1,1956.1,1956.0,1956.2,1956.0,1956.2,1956.4,1955.7,1955.9,1955.7,1955.6,1955.5,1955.1,1954.9,1955.3,1955.
6,1960.8,1960.3,1960.8,1960.8,1961.5,1961.7,1961.7,1961.9,1961.9,1962.1,1961.9,1962.3,1962.2,1962.6,1962.4,1962.5,1961.7,1961.6,1961.7,1961.7,1961.7,1960.9,1960.2,1960.6,1961.1,1961.5,1961.6,1961.5,1961.3,1961.6,1961.4,1961.7,1963.1,1963.1,1963.7,1963.2,1962.9,1962.9,1962.4,1962.1,1961.5,1961.6,1961.5,1961.7,1961.1,1960.7,1960.2,1959.9,1960.4,1960.7,1960.8,1961.3,1962.2,1962.0,1962.5,1962.4,1962.1,1962.6,1963.0,1962.7,1962.7,1962.6,1963.0,1963.5,1963.4,1963.6,1962.9,1963.1,1962.8,1962.8,1962.8,1963.3,1963.0,1963.8,1963.2,1963.2,1 ...

# %%
start = "2023-06-24T00:00:00Z"
end = "2023-07-26T23:59:59Z"

#start = "2023-03-24T00:00:00Z"
#end = "2023-06-23T23:59:59Z"

ticker = "RTYU23"
ts = TS_Auth(API_KEY, API_SECRET_KEY)
ts.start_auth0()

access_token = ts.get_access_token()

#start_datetime, end_datetime = getDatetimeSpanForWeekNumber(2023, 28)
start_datetime = '2023-08-08T04:00:00Z'
end_datetime = '2023-08-08T04:10:00Z'

start_datetime = '2023-08-09T14:20:00Z'
end_datetime = '2023-08-09T14:30:00Z'

ticker = "RTYU23"
unit = "Minute"
#url = f"https://api.tradestation.com/v3/marketdata/barcharts/{ticker}?interval=1&unit={unit}&firstdate={start_datetime}&lastdate={end_datetime}"
url = f"https://api.tradestation.com/v3/marketdata/barcharts/{ticker}?interval=1&unit={unit}&firstdate={start_datetime}"

#url = "https://sim-api.tradestation.com/v3/marketdata/barcharts/RTYU23?interval=1&unit=Minute&firstdate=2023-06-28T15:30:00Z&lastdate=2023-07-20T16:30:00Z"
print(url)  
headers = {'Authorization': f'Bearer {access_token}' }

response = requests.request("GET", url, headers=headers)
print(response.status_code)
json_data = response.json()
print(json_data)
for bar in json_data['Bars']:
    print(bar['TimeStamp'], bar['BarStatus'], bar['Open'], bar['High'], bar['Low'], bar['Close'], bar['TotalVolume'])
# Out:
# Attempting to get access token using previous refresh token pSJFzMb5j1rLboefn26X-18fMuHqyWUMkCrKS079x60Hf
# Access token is expired, requesting a new one...
# Got access token using previous refresh token
# Access token already exists and is valid, skipping login
# Access token is still valid, 1169.3803758621216 seconds left until expiration
# https://api.tradestation.com/v3/marketdata/barcharts/RTYU23?interval=1&unit=Minute&firstdate=2023-08-09T14:20:00Z&lastdate=2023-08-09T14:30:00Z
# 400
# {'Error': 'BadRequest', 'Message': 'lastdate cannot be a future date.'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 31
#      29 json_data = response.json()
#      30 print(json_data)
# ---> 31 for bar in json_data['Bars']:
#      32     print(bar['TimeStamp'], bar['BarStatus'], bar['Open'], bar['High'], bar['Low'], bar['Close'], bar['TotalVolume'])
#
# KeyError: 'Bars'
